# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("C:\\Users\\plear\\Documents\\Projects\\Machine-learning\\house_price.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  680000
# 4  4000       5.0    8  725000

# %%
# %matplotlib inline
plt.xlabel("area(sqr ft)")
plt.ylabel  ("price(US$)")
plt.scatter(df.area,df.price,color="red",marker="+")

# %%
lin_reg = linear_model.LinearRegression()
lin_reg.fit(df[["area"]],df.price)
# Out:
# LinearRegression()

# %%
# lin_reg.predict([3300])
lin_reg.coef_
# Out:
# array([135.78767123])

# %%
predicted_price = lin_reg.predict([[33000]])
print(predicted_price)
# Out:
# [4661609.5890411]
# c:\Users\plear\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
lin_reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
# %matplotlib inline
plt.xlabel("area(sqr ft)")
plt.ylabel  ("price(US$)")
plt.scatter(df.area,df.price,color="red",marker="+")
plt.plot(df.area,lin_reg.predict(df[["area"]]),color="blue")
